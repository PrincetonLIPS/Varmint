# %%
from IPython.display import Video

import jax.numpy as np
import pickle

import matplotlib.pyplot as plt

import experiment_utils as eutils

DATASET_ROOT = '/n/fs/mm-iga/Varmint/slurm_experiments/'

import sys
sys.argv = ['foo']  # eutils uses argparse, so this needs to be defined as a dummy for it to work.

# %%
tanhexp = eutils.read_surrogate_experiment(DATASET_ROOT, 'newdataset', 'tanhsimple')
tanhbigexp = eutils.read_surrogate_experiment(DATASET_ROOT, 'newdataset', 'tanhsimplebigger')

plt.plot(tanhexp.iters, tanhexp.train_losses, label='Train Small')
plt.plot(tanhexp.iters, tanhexp.test_losses, label='Test Small')
plt.plot(tanhbigexp.iters, tanhbigexp.train_losses, label='Train Big')
plt.plot(tanhbigexp.iters, tanhbigexp.test_losses, label='Test Big')
plt.yscale('log')
plt.legend()

# %%
df = eutils.gather_experiment_df('/n/fs/mm-iga/Varmint/slurm_experiments/smallsingleexampledataset/trained_surrogates/', r"^simplesteppersweep-[\d]+$", 'model.pkl')

# %%
df['SUCCESS'].value_counts()

# %%
df_success = df[df['SUCCESS']]

# %%
df_success.loss_type.value_counts()

# %%
params = zip(list(df_success['dsroot']), list(df_success['dsname']), list(df_success['exp_name']))

exps = []
for param in params:
    try:
        exp = eutils.read_surrogate_experiment(*param)
        exps.append(exp)
    except:
        print(f'Experiment {param[2]} could not be read.')

# %%
cs = {
    'tanh': 'red',
    'selu': 'green',
    'relu': 'blue'
}

plt.figure(figsize=(16, 10))
for exp in exps:
    plt.plot(exp.iters, exp.train_losses, c=cs[exp.args['nn_activation']])
    print(exp.train_losses)
    plt.yscale('log')

plt.savefig('experimentfig.png')

# %%
df = eutils.gather_experiment_df('/n/fs/mm-iga/Varmint/slurm_experiments/smallsingleexampledataset/trained_surrogates/', r"^skipconnectwithmetrics-[\d]+$", 'model.pkl')
print(df['SUCCESS'].value_counts())
df_success = df[df['SUCCESS']]
# Out:
# True     72
# False     9
# Name: SUCCESS, dtype: int64

# %%
df_success
# Out:
#                        exp_name  \
# 0   skipconnectwithmetrics-0057
# 1   skipconnectwithmetrics-0020
# 4   skipconnectwithmetrics-0059
# 6   skipconnectwithmetrics-0013
# 7   skipconnectwithmetrics-0043
# ..                          ...
# 76  skipconnectwithmetrics-0056
# 77  skipconnectwithmetrics-0058
# 78  skipconnectwithmetrics-0023
# 79  skipconnectwithmetrics-0052
# 80  skipconnectwithmetrics-0048
#
#                                              exp_root  seed  overwrite  \
# 0   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...     1      False
# 1   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...     3      False
# 4   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...     3      False
# 6   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...     2      False
# 7   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...     2      False
# ..                                                ...   ...        ...
# 76  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...     3      False
# 77  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...     2      False
# 78  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...     3      False
# 79  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...     2      False
# 80  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...     1      False
#
#                                      dsroot                     dsname  \
# 0   /n/fs/mm-iga/Varmint/slurm_experiments/  smallsingleexampledataset
# 1   /n/fs/mm-iga/Varmint/slurm_experiments/  smallsingleexampledataset
# 4   /n/fs/mm-iga/Varmint/slurm_experiments/  smallsingleexampledataset
# 6   /n/fs/mm-iga/Varmint/slurm_experiments/  smallsingleexampledataset
# 7   /n/fs/mm-iga/Varmint/slurm_experiments/  smallsingleexampledataset
# ..                                      ...                        ...
# 76  /n/fs/mm-iga/Varmint/slurm_experiments/  smallsingleexampledataset
# 77  /n/fs/mm-iga/Varmint/slurm_experiments/  smallsingleexampledataset
# 78  /n/fs/mm-iga/Varmint/slurm_experiments/  smallsingleexampledataset
# 79  /n/fs/mm-iga/Varmint/slurm_experiments/  smallsingleexampledataset
# 80  /n/fs/mm-iga/Varmint/slurm_experiments/  smallsingleexampledataset
#
#     stepsize  batchsize  numiters  skip_weight  ...  \
# 0      0.001        100    100000         0.01  ...
# 1      0.001        100    100000         0.01  ...
# 4      0.001        100    100000         0.01  ...
# 6      0.001        100    100000         0.01  ...
# 7      0.001        100    100000         0.01  ...
# ..       ...        ...       ...          ...  ...
# 76     0.001        100    100000         0.01  ...
# 77     0.001        100    100000         0.01  ...
# 78     0.001        100    100000         0.01  ...
# 79     0.001        100    100000         0.01  ...
# 80     0.001        100    100000         0.01  ...
#
#                                                 dsdir  \
# 0   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...
# 1   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...
# 4   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...
# 6   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...
# 7   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...
# ..                                                ...
# 76  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...
# 77  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...
# 78  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...
# 79  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...
# 80  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...
#
#                                               exp_dir ntrain  nfeat  nrad  \
# 0   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...   1600    150    16
# 1   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...   1600    150    16
# 4   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...   1600    150    16
# 6   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...   1600    150    16
# 7   /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...   1600    150    16
# ..                                                ...    ...    ...   ...
# 76  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...   1600    150    16
# 77  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...   1600    150    16
# 78  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...   1600    150    16
# 79  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...   1600    150    16
# 80  /n/fs/mm-iga/Varmint/slurm_experiments/smallsi...   1600    150    16
#
#    ntest SUCCESS      m_final_train_loss       m_final_test_loss  m_num_iters
# 0    400    True  0.00016476819630659533  0.00016476819630659533     100000.0
# 1    400    True  0.00016697446206597293  0.00016697446206597293     100000.0
# 4    400    True  0.00016478637336545557  0.00016478637336545557     100000.0
# 6    400    True  0.00016471482559869815  0.00016471482559869815     100000.0
# 7    400    True  0.00016589660726091369  0.00016589660726091369     100000.0
# ..   ...     ...                     ...                     ...          ...
# 76   400    True  0.00016493597682490512  0.00016493597682490512     100000.0
# 77   400    True  0.00016472365402226807  0.00016472365402226807     100000.0
# 78   400    True  0.00016440796879191606  0.00016440796879191606     100000.0
# 79   400    True  0.00016717421096628456  0.00016717421096628456     100000.0
# 80   400    True  0.00016467348255190276  0.00016467348255190276     100000.0
#
# [72 rows x 26 columns]

# %%
print(df_success['m_final_train_loss'].min())
print(df_success['m_final_train_loss'].max())
# Out:
# 0.00016440796879191606
# 0.00016957217467851362

# %%
0.00016577006834306507
# Out:
# 0.00016577006834306507

# %%
params = zip(list(df_success['dsroot']), list(df_success['dsname']), list(df_success['exp_name']))

exps = []
for param in params:
    try:
        exp = eutils.read_surrogate_experiment(*param)
        exps.append(exp)
    except:
        print(f'Experiment {param[2]} could not be read.')

# %%
cs = {
    'tanh': 'red',
    'selu': 'green',
    'relu': 'blue'
}

plt.figure(figsize=(16, 10))
for exp in exps:
    iters = [s[0] for s in exp.train_losses]
    train_losses = [s[1] for s in exp.train_losses]
    plt.plot(iters, train_losses, c=cs[exp.args['nn_activation']])
    plt.yscale('log')

# %%
df = eutils.gather_experiment_df('/n/fs/mm-iga/Varmint/slurm_experiments/smallsingleexampledataset/trained_surrogates/', r"^skipconnectwithmetricsSGD-[\d]+$", 'model.pkl')
print(df['SUCCESS'].value_counts())
df_success = df[df['SUCCESS']]
# Out:
# True    81
# Name: SUCCESS, dtype: int64

# %%
print(df_success['m_final_train_loss'].min())
print(df_success['m_final_train_loss'].max())
# Out:
# 0.0001669803302687086
# 0.00029415011263258606
