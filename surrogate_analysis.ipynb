# %%
import jax.numpy as np
import pickle

import matplotlib.pyplot as plt

import experiment_utils as eutils

DATASET_ROOT = '/n/fs/mm-iga/Varmint/slurm_experiments/newdataset/'

import sys
sys.argv = ['foo']  # eutils uses argparse, so this needs to be defined as a dummy for it to work.

# %%
tanhexp = eutils.read_surrogate_experiment(DATASET_ROOT, 'tanhsimple')

plt.plot(tanhexp.iters, tanhexp.train_losses, label='Train')
plt.plot(tanhexp.iters, tanhexp.test_losses, label='Test')
plt.yscale('log')
plt.legend()
